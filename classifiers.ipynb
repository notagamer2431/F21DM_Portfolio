# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import tarfile
import urllib
import urllib.request
# Import for plotting
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

import seaborn as sns

# %%
df=pd.read_csv('/Users/mac/Downloads/ds_salaries.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.drop(columns=df.columns[0], axis=1, inplace=True)

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
X= df.drop('company_location', axis=1)
X.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_size
# 0            L
# 1            S
# 2            M
# ...

# %%
y=df['company_location']
y.head(10)
# Out:
# 0    DE
# 1    JP
# 2    GB
# 3    HN
# 4    US
# 5    US
# 6    US
# 7    HU
# 8    US
# 9    NZ
# Name: company_location, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test ,y_train,y_test =train_test_split(X,y,test_size=0.3,random_state=21)

# %%
y_test
# Out:
# 96     US
# 431    ES
# 362    CA
# 577    US
# 549    US
#        ..
# 115    US
# 164    DE
# 276    US
# 127    IN
# 199    US
# Name: company_location, Length: 183, dtype: object

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipeline = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

# %%
cat_pipeline = Pipeline([
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("cat_encoder", OneHotEncoder(sparse=False)),
    ])

# %%
from sklearn.compose import ColumnTransformer
num_attribs = ["salary", "salary_in_usd"]
cat_attribs = ["work_year", "experience_level", "employment_type", "job_title","salary_currency","employee_residence","company_size","remote_ratio"]

preprocess_pipeline = ColumnTransformer([
        ("num", num_pipeline, num_attribs),
        ("cat", cat_pipeline, cat_attribs),
    ])

# %%
X_train = preprocess_pipeline.fit_transform(
    X_train[num_attribs + cat_attribs])
X_train
# Out:
# array([[-0.07415881,  1.49092687,  0.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.19224582, -1.30513033,  1.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.14294736, -0.44418415,  0.        , ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [-0.12288403,  0.32609718,  0.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.14008117, -0.08501919,  1.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.1056869 ,  0.73721354,  0.        , ...,  1.        ,
#          0.        ,  0.        ]])

# %%
from sklearn.ensemble import RandomForestClassifier

forest_clf = RandomForestClassifier(n_estimators=100, random_state=42)
forest_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
X_test
# Out:
#      work_year experience_level employment_type                   job_title  \
# 96        2021               EN              PT                AI Scientist
# 431       2022               MI              FT                Data Analyst
# 362       2022               SE              FT                Data Analyst
# 577       2022               SE              FT                Data Analyst
# 549       2022               SE              FT               Data Engineer
# ..         ...              ...             ...                         ...
# 115       2021               EN              FT  Machine Learning Scientist
# 164       2021               EX              FT    Director of Data Science
# 276       2021               EN              FT              Data Scientist
# 127       2021               MI              FT              Data Scientist
# 199       2021               EN              FT     Data Science Consultant
#
# ...

# %%
y_test
# Out:
# 96     US
# 431    ES
# 362    CA
# 577    US
# 549    US
#        ..
# 115    US
# 164    DE
# 276    US
# 127    IN
# 199    US
# Name: company_location, Length: 183, dtype: object

# %%
X_test = preprocess_pipeline.fit_transform(
    X_test[num_attribs + cat_attribs])
    
X_test
# Out:
# array([[-0.27593666, -1.56339531,  0.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.25632212, -1.24452011,  0.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.14735246,  0.23060078,  0.        , ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [-0.22581061, -0.8640409 ,  0.        , ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.47377464, -1.60192062,  0.        , ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.19094032, -0.37753349,  0.        , ...,  0.        ,
#          0.        ,  1.        ]])

# %%
y_pred = forest_clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 y_pred = forest_clf.predict(X_test)
#
# File ~/opt/anaconda3/envs/F21DL/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:832, in ForestClassifier.predict(self, X)
#     811 def predict(self, X):
#     812     """
#     813     Predict class for X.
#     814
#    (...)
#     830         The predicted classes.
#     831     """
# --> 832     proba = self.predict_proba(X)
#     834     if self.n_outputs_ == 1:
#     835         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~/opt/anaconda3/envs/F21DL/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:874, in ForestClassifier.predict_proba(self, X)
#     872 check_is_fitted(self)
#     873 # Check data
# --> 874 X = self._validate_X_predict(X)
#     876 # Assign chunk of trees to jobs
# ...
